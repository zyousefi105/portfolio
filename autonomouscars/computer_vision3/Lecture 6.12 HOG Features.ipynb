# %% [markdown]
# ## CODE TO PERFORM HISTOGRAM OF ORIENTED GRADIENTS
# ## Dr. Ryan Ahmed

# %% [markdown]
# # LOAD/DISPLAY IMAGE

# %%
import cv2
import numpy as np
import matplotlib.image as mpimg
from matplotlib import pyplot as plt
from skimage.feature import hog # The Histogram of Oriented Gradient (HOG)

# %matplotlib inline

# %%
image_color = cv2.imread('truck_free_s.jpg')
cv2.imshow('Find Truck corners', image_color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
plt.imshow(image_color)

# %% [markdown]
# ## CONVERT TO GREYSCALE

# %%
image_gray = cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray, cmap = 'gray')

# %%
image_gray.shape
# Out:
# (678, 957)

# %%
# Sobel Calculations
x_sobel = cv2.Sobel(image_gray, cv2.CV_64F, 0, 1, ksize = 7)
cv2.imshow('Sobel - X direction', x_sobel)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# Sobel Calculations
y_sobel = cv2.Sobel(image_gray, cv2.CV_64F, 1, 0, ksize = 7)
cv2.imshow('Sobel - Y direction', y_sobel)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # PERFORM HISTOGRAM OF ORIENTED GRADIENT

# %%
features, hog_image = hog(image_gray, 
                                   orientations = 9, 
                                   pixels_per_cell = (16, 16), 
                                   cells_per_block = (1, 1), 
                                   transform_sqrt = False, 
                                   visualize = True, 
                                   feature_vector = False)

features.shape
# Out:
# C:\Users\Dr. Ryan\Anaconda3\lib\site-packages\skimage\feature\_hog.py:150: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15. To supress this message specify explicitly the normalization method.
#   skimage_deprecation)
# (42, 59, 1, 1, 9)

# %%
features[30,50,:]
# Out:
# array([[[0.2893337 , 0.04713659, 0.0136775 , 0.03014444, 0.02844146,
#          0.03502109, 0.02576389, 0.04299744, 0.48748364]]])

# %%
hog_image.shape
# Out:
# (678, 957)

# %%
# Return image after stretching or shrinking its intensity levels.
from skimage import exposure

hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 2))

# %%
plt.figure()    
plt.imshow(hog_image_rescaled, cmap = 'gray')
plt.title('HOG Features')
# Out:
# Text(0.5,1,'HOG Features')

# %% [markdown]
# # Well Done!
